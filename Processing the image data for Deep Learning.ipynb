# %% [markdown]
# <a href="https://colab.research.google.com/github/arunmadapathi-1609/Deep-Learning-using-the-python.ipynb/blob/main/Processing%20the%20image%20data%20for%20Deep%20Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Processing the Image Data For Deep Learning

# %%
#getting the image using web get
# !wget 'https://th.bing.com/th/id/R.04af124ef7e818090f1487b471308cc4?rik=s%2fPMBwyCoNKBCw&riu=http%3a%2f%2fgetwallpapers.com%2fwallpaper%2ffull%2f6%2f1%2f5%2f959887-puppy-wallpaper-desktop-2048x1536-iphone.jpg&ehk=7MigmYmZMLW%2bYhlk4Uet5kp%2fUZttrWbFE4wgGSWB0rc%3d&risl=&pid=ImgRaw&r=0'
# Out:
# The destination name is too long (245), reducing to 236
# --2025-08-11 20:43:25--  https://th.bing.com/th/id/R.04af124ef7e818090f1487b471308cc4?rik=s%2fPMBwyCoNKBCw&riu=http%3a%2f%2fgetwallpapers.com%2fwallpaper%2ffull%2f6%2f1%2f5%2f959887-puppy-wallpaper-desktop-2048x1536-iphone.jpg&ehk=7MigmYmZMLW%2bYhlk4Uet5kp%2fUZttrWbFE4wgGSWB0rc%3d&risl=&pid=ImgRaw&r=0
# Resolving th.bing.com (th.bing.com)... 23.213.34.91, 23.213.34.80, 23.213.34.73, ...
# Connecting to th.bing.com (th.bing.com)|23.213.34.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 501369 (490K) [image/jpeg]
# Saving to: ‘R.04af124ef7e818090f1487b471308cc4?rik=s%2FPMBwyCoNKBCw&riu=http:%2F%2Fgetwallpapers.com%2Fwallpaper%2Ffull%2F6%2F1%2F5%2F959887-puppy-wallpaper-desktop-2048x1536-iphone.jpg&ehk=7MigmYmZMLW+Yhlk4Uet5kp%2FUZttrWbFE4wgGSWB0rc=&risl=&pid=I’
#
# R.04af124ef7e818090 100%[===================>] 489.62K  2.59MB/s    in 0.2s
#
# ...

# %%
#Libraries used for the image processing
# 1 -> matplotlib.image
#2 -> pillow
#3 -> opencv

# %%
#importing the image module from matplotlib library
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# loading the image through the matplotlib.image module

img=mpimg.imread('/content/dog image')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1536, 2048, 3)

# %%
print(img)
# Out:
# [[[ 91  89  51]
#   [ 91  89  51]
#   [ 91  89  51]
#   ...
#   [ 92 100  41]
#   [ 94 102  43]
#   [ 95 103  44]]
#
#  [[ 91  89  51]
#   [ 91  89  51]
#   [ 90  88  50]
#   ...
#   [ 92 100  41]
#   [ 94 102  43]
#   [ 95 103  44]]
#
#  [[ 90  88  50]
#   [ 90  88  50]
#   [ 90  88  50]
#   ...
#   [ 93 101  42]
#   [ 95 103  46]
#   [ 95 103  46]]
#
#  ...
#
#  [[ 82  61  56]
#   [ 73  52  47]
#   [ 46  27  21]
#   ...
#   [ 26   6   7]
#   [ 27   7   8]
#   [ 26   6   7]]
#
#  [[ 88  67  62]
#   [ 83  62  57]
#   [ 55  36  30]
#   ...
#   [ 23   4   6]
#   [ 23   3   5]
#   [ 20   0   2]]
#
#  [[ 65  44  39]
#   [ 68  47  42]
#   [ 48  29  23]
#   ...
#   [ 18   0   1]
#   [ 20   0   2]
#   [ 21   1   3]]]

# %%
# displaying the image from the numpyarray

img_plt=plt.imshow(img)
plt.show()

# %%
#Resizing the image using the pillow library
from PIL import Image

# %%
img=Image.open('/content/dog image')
img_resized=img.resize((200,200))

# %%
img_resized.save('dog_image_resized.jpg')

# %%
img=mpimg.imread('/content/dog_image_resized.jpg')

img_plt=plt.imshow(img)
plt.show()

# %%
# converting the RGB images to Grayscale image using openCv

#importing the openCV library
import cv2

# %%
img=cv2.imread('/content/dog image')

# %%
img.shape
# Out:
# (1536, 2048, 3)

# %%
Grayscale_image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
Grayscale_image.shape
# Out:
# (1536, 2048)

# %%
  from google.colab.patches import cv2_imshow

# %%
#displaying the image
cv2_imshow(Grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=2048x1536>
